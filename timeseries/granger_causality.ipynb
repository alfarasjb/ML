# %%
from statsmodels.tsa.stattools import grangercausalitytests 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# random time series AR(1) 
t1 = [0.1 * np.random.normal()] 
for _ in range(100): 
    t1.append(0.5 * t1[-1] + 0.1 * np.random.normal()) 

t2 = [item + 0.1 * np.random.normal() for item in t1]

# %%
t1 = t1[3:] 
t2 = t2[:-3]

# %%
plt.figure(figsize=(10, 4)) 
plt.plot(t1, color='b')
plt.plot(t2, color='r') 

plt.legend(['t1', 't2'], fontsize=16)

# %%
# is time series 2 granger caused by t1? 
# we need a df and the order for granger causality test library
ts_df = pd.DataFrame(columns=['t2', 't1'], data=zip(t2, t1)) 
ts_df
# Out:
#           t2        t1
# 0   0.023588  0.123399
# 1   0.013500  0.228555
# 2   0.081764  0.265856
# 3  -0.031134  0.230808
# 4   0.310654 -0.036048
# ..       ...       ...
# 93 -0.238495  0.013581
# 94  0.120950 -0.006488
# 95 -0.199269 -0.148926
# 96 -0.019511 -0.109300
# 97 -0.237150 -0.020434
#
# [98 rows x 2 columns]

# %%
gc_res = grangercausalitytests(ts_df, 3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1738  , p=0.0781  , df_denom=94, df_num=1
# ssr based chi2 test:   chi2=3.2751  , p=0.0703  , df=1
# likelihood ratio test: chi2=3.2210  , p=0.0727  , df=1
# parameter F test:         F=3.1738  , p=0.0781  , df_denom=94, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.0045 , p=0.0000  , df_denom=91, df_num=2
# ssr based chi2 test:   chi2=25.3282 , p=0.0000  , df=2
# likelihood ratio test: chi2=22.4785 , p=0.0000  , df=2
# parameter F test:         F=12.0045 , p=0.0000  , df_denom=91, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=46.2553 , p=0.0000  , df_denom=88, df_num=3
# ssr based chi2 test:   chi2=149.8041, p=0.0000  , df=3
# likelihood ratio test: chi2=89.9252 , p=0.0000  , df=3
# parameter F test:         F=46.2553 , p=0.0000  , df_denom=88, df_num=3
